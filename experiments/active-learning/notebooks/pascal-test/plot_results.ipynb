# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# x = [0, 1, 2, 3, 4, 5, 6]
# y_random = [0.1421, 0.151, 0.1465, 0.1718, 0.1508, 0.1684, 0.1625]
# y_entropy = [0.1395, 0.136, 0.1653, 0.141, 0.1429, 0.1414, 0.1367]
# y_cluster = [0.1396, 0.1452, 0.1579, 0.1603, 0.1495, 0.1565, 0.1669]
x = [0, 6]
y_random = [0.1421, 0.1625]
y_entropy = [0.1395, 0.1367]
y_cluster = [0.1396, 0.1669]

# %%
# plot the data
plt.plot(x, y_random, marker='o', label='Random')

# plot the entropy data
plt.plot(x, y_entropy, marker='^', label='Entropy')

# plot the entropy cluster data
# plt.plot(x, y_entropy_cluster, marker='s', label='Entropy-Cluster')

# plot the batchbald data
# plt.plot(x, y_batchbald, marker='s', label='BatchBALD')

# plot the cluster data
plt.plot(x, y_cluster, marker='s', label='Core-set')

# labels
plt.xlabel('Active Learning Rounds')
plt.ylabel('Accuracy')

# xticks are integers
plt.xticks(np.arange(0, 6, 1))

# xlim
plt.xlim(0, 6)

# ylim
plt.ylim(0.13, 0.2)

plt.grid(True)
plt.legend()
plt.show()
